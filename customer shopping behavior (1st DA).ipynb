# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cust_df=pd.read_csv(r"C:\Users\hp\Downloads\customer_shopping_behavior.csv")

# %%
cust_df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
cust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
cust_df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
cust_df.nunique()
# Out:
# Customer ID               3900
# Age                         53
# Gender                       2
# Item Purchased              25
# Category                     4
# Purchase Amount (USD)       81
# Location                    50
# Size                         4
# Color                       25
# Season                       4
# Review Rating               26
# Subscription Status          2
# Shipping Type                6
# Discount Applied             2
# Promo Code Used              2
# Previous Purchases          50
# Payment Method               6
# Frequency of Purchases       7
# dtype: int64

# %%
cust_df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
cust_df['Review Rating']=cust_df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
cust_df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
cust_df.columns=cust_df.columns.str.lower()
cust_df.columns=cust_df.columns.str.replace(' ','_')

# %%
cust_df=cust_df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})
cust_df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
cust_df.transpose()
# Out:
#                                0            1              2             3     \
# customer_id                       1            2              3             4
# age                              55           19             50            21
# gender                         Male         Male           Male          Male
# item_purchased               Blouse      Sweater          Jeans       Sandals
# category                   Clothing     Clothing       Clothing      Footwear
# purchase_amount                  53           64             73            90
# location                   Kentucky        Maine  Massachusetts  Rhode Island
# size                              L            L              S             M
# color                          Gray       Maroon         Maroon        Maroon
# season                       Winter       Winter         Spring        Spring
# review_rating                   3.1          3.1            3.1           3.5
# ...

# %%
(cust_df['discount_applied']==cust_df['promo_code_used']).all()
# Out:
# np.True_

# %%
cust_df.drop(columns='promo_code_used',inplace=True)

# %%
cust_df.transpose()
# Out:
#                                0            1              2             3     \
# customer_id                       1            2              3             4
# age                              55           19             50            21
# gender                         Male         Male           Male          Male
# item_purchased               Blouse      Sweater          Jeans       Sandals
# category                   Clothing     Clothing       Clothing      Footwear
# purchase_amount                  53           64             73            90
# location                   Kentucky        Maine  Massachusetts  Rhode Island
# size                              L            L              S             M
# color                          Gray       Maroon         Maroon        Maroon
# season                       Winter       Winter         Spring        Spring
# review_rating                   3.1          3.1            3.1           3.5
# ...

# %%
labels=('Young Adult', 'Adult', 'Middle-aged', 'Senior') 
cust_df['age_group']=pd.qcut(cust_df['age'],q=4,labels=labels)

# %%
cust_df[['age','age_group']]
# Out:
#       age    age_group
# 0      55  Middle-aged
# 1      19  Young Adult
# 2      50  Middle-aged
# 3      21  Young Adult
# 4      45  Middle-aged
# ...   ...          ...
# 3895   40        Adult
# 3896   52  Middle-aged
# 3897   46  Middle-aged
# 3898   44        Adult
# 3899   52  Middle-aged
#
# [3900 rows x 2 columns]

# %%
pd.qcut(cust_df['age'], q=4)
# Out:
# 0         (44.0, 57.0]
# 1       (17.999, 31.0]
# 2         (44.0, 57.0]
# 3       (17.999, 31.0]
# 4         (44.0, 57.0]
#              ...
# 3895      (31.0, 44.0]
# 3896      (44.0, 57.0]
# 3897      (44.0, 57.0]
# 3898      (31.0, 44.0]
# 3899      (44.0, 57.0]
# Name: age, Length: 3900, dtype: category
# Categories (4, interval[float64, right]): [(17.999, 31.0] < (31.0, 44.0] < (44.0, 57.0] < (57.0, 70.0]]

# %%
cust_df['frequency_of_purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
frequency_mapping={'Fortnightly':14,
                   'Weekly':7,
                   'Annually':365,
                   'Quarterly':90,
                   'Bi-Weekly':14,
                   'Monthly':30,
                   'Every 3 Months':90}
cust_df['days_frequency']=cust_df['frequency_of_purchases'].map(frequency_mapping)

# %%
cust_df[['days_frequency','frequency_of_purchases']]
# Out:
#       days_frequency frequency_of_purchases
# 0                 14            Fortnightly
# 1                 14            Fortnightly
# 2                  7                 Weekly
# 3                  7                 Weekly
# 4                365               Annually
# ...              ...                    ...
# 3895               7                 Weekly
# 3896              14              Bi-Weekly
# 3897              90              Quarterly
# 3898               7                 Weekly
# 3899              90              Quarterly
#
# [3900 rows x 2 columns]

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# ...
#   Using cached mysqlclient-2.2.7.tar.gz (91 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build mysqlclient
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [77 lines of output]
#   C:\Users\hp\AppData\Local\Temp\pip-build-env-f862a6vk\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#   !!
#
#           ********************************************************************************
# ...

# %%
from sqlalchemy import create_engine

user='root'
password=7275001553
host='localhost'
port=3306
database='customer'
               

engine= create_engine(f"mysql+pymysql://root:7275001553@localhost:3306/customer")

table_name='behaviour'
cust_df.to_sql(table_name,engine,if_exists='replace',index=False)
print('data loaded in table',table_name,'and database',database)
# Out:
# data loaded in table behaviour and database customer
